# %%
# %load_ext autoreload
# %autoreload 2
from model import NeuralNetwork
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sizes = [500, 400, 200, 100, 10, 100, 200, 400, 500, 784]
nn = NeuralNetwork(sizes)

nn.train_DATA_PATH = "data/mnist_train.csv"
nn.test_DATA_PATH = "data/mnist_test.csv"

# %%
train_data, train_labels, test_data, test_labels = nn.data()
# Out:
# INFO: Data loaded correctly
# INFO: Train and test data loaded

# %%
nn.latent_index = 5
nn.activation_functions = [
    "relu",
    "relu",
    "relu",
    "relu",
    "sigmoid",
    "relu",
    "relu",
    "relu",
    "relu",
    "sigmoid"
]
nn.adam_beta1 = 0.9
nn.adam_beta2 = 0.999
nn.adam_eps = 1E-8
nn.optimizer = "adam"
nn.batch_prints = 4
params = nn.train(epochs=3, lr=0.0001, batch_size=64, train_type="batch", log = True)
# Out:
# INFO: Data loaded correctly
# INFO: Train and test data loaded
# Data load time:  2.752689916000236 s
# INFO: Model parameters init correct
# Epoch:  0
# Batch:  0 / 937
# Reconstruction loss:  0.47117323180048387
# Estimated precision: 52.88267681995161 %
# /home/pablo/dev/ai-learning/04_mnist_autoencoder/src/model.py:80: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1 + np.exp(-Z))
# /home/pablo/dev/ai-learning/04_mnist_autoencoder/src/model.py:82: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1 + np.exp(-Z)) * (1 - 1.0 / (1 + np.exp(-Z)))
# Epoch:  0
# Batch:  234 / 937
# Reconstruction loss:  0.12084040697262304
# Estimated precision: 87.9159593027377 %
# Epoch:  0
# Batch:  468 / 937
# Reconstruction loss:  0.11616291551523682
# Estimated precision: 88.38370844847631 %
# Epoch:  0
# Batch:  702 / 937
# Reconstruction loss:  0.10098784489147093
# Estimated precision: 89.90121551085291 %
# Epoch:  0
# Batch:  936 / 937
# Reconstruction loss:  0.0796927749627576
# Estimated precision: 92.03072250372423 %
# Epoch:  1
# Batch:  0 / 937
# Reconstruction loss:  0.08469018015335433
# Estimated precision: 91.53098198466456 %
# Epoch:  1
# Batch:  234 / 937
# Reconstruction loss:  0.07061316202256708
# Estimated precision: 92.9386837977433 %
# Epoch:  1
# Batch:  468 / 937
# Reconstruction loss:  0.07214556266550266
# Estimated precision: 92.78544373344974 %
# Epoch:  1
# Batch:  702 / 937
# Reconstruction loss:  0.06878298221596944
# Estimated precision: 93.12170177840305 %
# Epoch:  1
# Batch:  936 / 937
# Reconstruction loss:  0.06905758822581677
# Estimated precision: 93.09424117741833 %
# Epoch:  2
# Batch:  0 / 937
# Reconstruction loss:  0.0715201528775933
# Estimated precision: 92.84798471224067 %
# Epoch:  2
# Batch:  234 / 937
# Reconstruction loss:  0.06694583712428678
# Estimated precision: 93.30541628757132 %
# Epoch:  2
# Batch:  468 / 937
# Reconstruction loss:  0.07111963705461131
# Estimated precision: 92.88803629453886 %
# Epoch:  2
# Batch:  702 / 937
# Reconstruction loss:  0.06834274892214727
# Estimated precision: 93.16572510778526 %
# Epoch:  2
# Batch:  936 / 937
# Reconstruction loss:  0.0689237674187938
# Estimated precision: 93.10762325812063 %
# ---Epochs:  3
# ---Batch size:  64
# ---Learning rate:  0.001
# ---Optimizer:  adam
# ---Model precision:  93.17425271333614 %
# ---Time of training:  107.69000525899901 s

# %%
nn.plot_prediction(random.randint(0,9999), params, test_data, test_labels)

# %%
nn.latent_pred(random.randint(0,9), params)

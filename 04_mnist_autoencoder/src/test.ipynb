# %%
# %load_ext autoreload
# %autoreload 2
from model import NeuralNetwork
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_data, train_labels, test_data, test_labels = nn.data()
# Out:
# INFO: Data loaded correctly
# INFO: Train and test data loaded

# %%
sizes = [64, 784]
nn = NeuralNetwork(sizes)
nn.train_DATA_PATH = "data/mnist_train.csv"
nn.test_DATA_PATH = "data/mnist_test.csv"
nn.activation_functions = [
    "relu",
    "softmax"
]
nn.adam_beta1 = 0.9
nn.adam_beta2 = 0.999
nn.adam_eps = 1E-8
nn.optimizer = "gd"
nn.batch_prints = 1
params = nn.train(epochs=2, lr=0.001, batch_size=64, train_type="batch", log = True)
# Out:
# INFO: Data loaded correctly
# INFO: Train and test data loaded
# Data load time:  2.5490156559972093 s
# INFO: Model parameters init correct
# Epoch:  0
# Batch:  0 / 937
# Reconstruction loss:  0.10324817678302642
# Estimated precision: 89.67518232169735 %
# Epoch:  1
# Batch:  0 / 937
# Reconstruction loss:  0.10286978051667514
# Estimated precision: 89.71302194833248 %

# %%
nn.plot_prediction(random.randint(0,9999), params, test_data, test_labels)

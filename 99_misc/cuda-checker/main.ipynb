# %%
# Script para comprobar si CUDA (pytorch) está funcionando
import torch

if torch.cuda.is_available():
    print("CUDA is working.")
    print("CUDA version:", {torch.version.cuda})
    print(f"Device count: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"  Device {i}: {torch.cuda.get_device_name(i)}")
    x: Tensor = torch.rand(3, 3).cuda()
    print("Tensor on GPU:")
    print(x)
else:
    print("CUDA no está disponible.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Script para comprobar si CUDA (pytorch) está funcionando
#       2
# ----> 3 import torch
#       4
#       5 if torch.cuda.is_available():
#       6     print("CUDA is working.")
#
# File ~/dev/ai-learning/.venv/lib/python3.14/site-packages/torch/__init__.py:445
#     443     if USE_GLOBAL_DEPS:
#     444         _load_global_deps()
# --> 445     from torch._C import *  # noqa: F403
#     448 class SymInt:
#     449     """
#     450     Like an int (including magic methods), but redirects all operations on the
#     451     wrapped node. This is used in particular to symbolically record operations
#     452     in the symbolic shape workflow.
#     453     """
#
# ImportError: libcudnn.so.9: cannot open shared object file: No such file or directory

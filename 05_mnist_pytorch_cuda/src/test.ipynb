# %%
import torch

# %%
a = torch.rand(4,4)
print(a)
# Out:
# tensor([[0.9546, 0.4864, 0.6926, 0.4087],
#         [0.6116, 0.8989, 0.7347, 0.6062],
#         [0.0441, 0.4385, 0.5312, 0.9590],
#         [0.8985, 0.4381, 0.1972, 0.2535]])

# %%
a = a.view(-1,2)
print(a)
print(a.shape)
# Out:
# tensor([[0.9546, 0.4864],
#         [0.6926, 0.4087],
#         [0.6116, 0.8989],
#         [0.7347, 0.6062],
#         [0.0441, 0.4385],
#         [0.5312, 0.9590],
#         [0.8985, 0.4381],
#         [0.1972, 0.2535]])
# torch.Size([8, 2])

# %%
dict = {
    "A": 11,
    "B": 22,
    "C": 33
}


for i, (label, data) in enumerate(a):
    print(i)
    print(label)
    print(data)
# Out:
# 0
# tensor(0.9546)
# tensor(0.4864)
# 1
# tensor(0.6926)
# tensor(0.4087)
# 2
# tensor(0.6116)
# tensor(0.8989)
# 3
# tensor(0.7347)
# tensor(0.6062)
# 4
# tensor(0.0441)
# tensor(0.4385)
# 5
# tensor(0.5312)
# tensor(0.9590)
# 6
# tensor(0.8985)
# tensor(0.4381)
# 7
# tensor(0.1972)
# tensor(0.2535)
